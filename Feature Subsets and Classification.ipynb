# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.grid_search import GridSearchCV
from sklearn.cross_validation import train_test_split
from sklearn.metrics import roc_auc_score
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.feature_selection import SelectFromModel

import xgboost as xgb

from dataio import getdata, writesub

# %%
feats5 = pd.read_csv("feature_combos_5.csv")
feats10 = pd.read_csv("feature_combos_10.csv")
feats15 = pd.read_csv("feature_combos_15.csv")

trainpath = 'train.csv'
testpath = 'test.csv'
df_train, df_test = getdata(trainpath,testpath)

# %%
feats5.head(10)
# Out:
#    Unnamed: 0     feature1                feature2                feature3  \
# 0           0        var15             saldo_var42               num_var35
# 1           1        var15             saldo_var42               num_var35
# 2           2        var15  saldo_medio_var5_hace2                num_var4
# 3           3        var15             saldo_var42                num_var4
# 4           4        var15             saldo_var42               num_var35
# 5           5        var15             saldo_var42               num_var35
# 6           6  saldo_var30                   var15             saldo_var42
# 7           7  saldo_var30                   var15  saldo_medio_var5_hace2
# 8           8        var15  saldo_medio_var5_hace2             saldo_var42
# 9           9        var15  saldo_medio_var5_hace2             saldo_var42
#
#                 feature4                feature5                feature6  \
# 0               num_var4   saldo_medio_var5_ult1              saldo_var5
# 1               num_var4               num_var30                   var36
# 2    num_meses_var5_ult3               num_var42                   var36
# 3             saldo_var5               num_var42                ind_var5
# 4             saldo_var5  saldo_medio_var5_hace3                   var36
# 5               num_var4   saldo_medio_var5_ult1              saldo_var5
# 6  saldo_medio_var5_ult1              saldo_var5                   var36
# 7            saldo_var42               num_var35   saldo_medio_var5_ult1
# 8  saldo_medio_var5_ult1     num_meses_var5_ult3  saldo_medio_var5_hace3
# 9  saldo_medio_var5_ult3               num_var30               num_var42
#
#                  feature7                  feature8           feature9  \
# 0                   var38               num_var30_0  imp_op_var41_ult1
# 1                   var38  num_meses_var39_vig_ult3        num_var30_0
# 2                   var38  num_meses_var39_vig_ult3        num_var30_0
# 3                   var38  num_meses_var39_vig_ult3        num_var30_0
# 4                   var38               ind_var39_0        ind_var41_0
# 5  saldo_medio_var5_hace3                  num_var5              var36
# 6                   var38  num_meses_var39_vig_ult3        num_var30_0
# 7               num_var30                 ind_var30          num_var42
# 8                   var38           num_var45_hace2     num_var45_ult1
# 9                num_var5                     var36              var38
#
#       ...              feature12          feature13    feature14  \
# 0     ...            ind_var13_0        num_var13_0  num_var42_0
# 1     ...      imp_op_var41_ult1        ind_var12_0    ind_var13
# 2     ...              num_var13        saldo_var13   num_var8_0
# 3     ...      imp_op_var39_ult1          ind_var13  num_var39_0
# 4     ...              ind_var13        num_var13_0   ind_var8_0
# 5     ...            ind_var39_0        ind_var12_0    ind_var13
# 6     ...            saldo_var13        num_var39_0  ind_var13_0
# 7     ...                  var38  imp_op_var41_ult1  num_var12_0
# 8     ...            num_var13_0        num_var42_0   num_var8_0
# 9     ...            num_var41_0          num_var13    ind_var13
#
#                  feature15                feature16                feature17  \
# 0               num_var8_0  imp_op_var41_efect_ult1           num_var22_ult3
# 1              ind_var13_0              num_var42_0           num_var45_ult3
# 2               ind_var8_0          num_var45_hace3           num_var22_ult3
# 3          num_var45_hace3           num_var22_ult3  imp_op_var39_efect_ult1
# 4          num_var45_hace3           num_var22_ult3        saldo_var13_corto
# 5              num_var13_0              num_var42_0               num_var8_0
# 6  imp_op_var41_efect_ult1           num_var45_ult3           num_var22_ult3
# 7              num_var13_0              num_var42_0  imp_op_var39_efect_ult1
# 8               ind_var8_0          num_var45_hace3           num_var22_ult3
# 9              num_var13_0              num_var42_0  imp_op_var41_efect_ult1
#
#                       feature18                     feature19  \
# 0               ind_var13_corto             saldo_var13_corto
# 1               ind_var13_corto             saldo_var13_corto
# 2               num_var13_corto  saldo_medio_var13_corto_ult3
# 3               ind_var13_corto             saldo_var13_corto
# 4  saldo_medio_var13_corto_ult3  saldo_medio_var13_corto_ult1
# 5       imp_op_var41_efect_ult1                num_var22_ult3
# 6       imp_op_var39_efect_ult1             saldo_var13_corto
# 7               ind_var13_corto               num_var13_corto
# 8       imp_op_var39_efect_ult1               num_var13_corto
# 9                num_var45_ult3       imp_op_var39_efect_ult1
#
#                       feature20 combinedAUC
# 0          ind_var43_recib_ult1    0.814596
# 1          ind_var43_recib_ult1    0.812961
# 2          ind_var43_recib_ult1    0.812723
# 3  saldo_medio_var13_corto_ult1    0.812225
# 4          ind_var43_recib_ult1    0.812082
# 5             saldo_var13_corto    0.812064
# 6          ind_var43_recib_ult1    0.811874
# 7  saldo_medio_var13_corto_ult1    0.811831
# 8             saldo_var13_corto    0.811699
# 9               ind_var13_corto    0.811232
#
# [10 rows x 22 columns]

# %%
feats10.head(10)
# Out:
#    Unnamed: 0     feature1                feature2                feature3  \
# 0           0        var15             saldo_var42               num_var35
# 1           1        var15             saldo_var42               num_var35
# 2           2        var15  saldo_medio_var5_hace2                num_var4
# 3           3        var15             saldo_var42                num_var4
# 4           4        var15             saldo_var42               num_var35
# 5           5        var15             saldo_var42               num_var35
# 6           6  saldo_var30                   var15             saldo_var42
# 7           7  saldo_var30                   var15  saldo_medio_var5_hace2
# 8           8        var15  saldo_medio_var5_hace2             saldo_var42
# 9           9        var15  saldo_medio_var5_hace2             saldo_var42
#
#                 feature4                feature5                feature6  \
# 0               num_var4   saldo_medio_var5_ult1              saldo_var5
# 1               num_var4               num_var30                   var36
# 2    num_meses_var5_ult3               num_var42                   var36
# 3             saldo_var5               num_var42                ind_var5
# 4             saldo_var5  saldo_medio_var5_hace3                   var36
# 5               num_var4   saldo_medio_var5_ult1              saldo_var5
# 6  saldo_medio_var5_ult1              saldo_var5                   var36
# 7            saldo_var42               num_var35   saldo_medio_var5_ult1
# 8  saldo_medio_var5_ult1     num_meses_var5_ult3  saldo_medio_var5_hace3
# 9  saldo_medio_var5_ult3               num_var30               num_var42
#
#                  feature7                  feature8           feature9  \
# 0                   var38               num_var30_0  imp_op_var41_ult1
# 1                   var38  num_meses_var39_vig_ult3        num_var30_0
# 2                   var38  num_meses_var39_vig_ult3        num_var30_0
# 3                   var38  num_meses_var39_vig_ult3        num_var30_0
# 4                   var38               ind_var39_0        ind_var41_0
# 5  saldo_medio_var5_hace3                  num_var5              var36
# 6                   var38  num_meses_var39_vig_ult3        num_var30_0
# 7               num_var30                 ind_var30          num_var42
# 8                   var38           num_var45_hace2     num_var45_ult1
# 9                num_var5                     var36              var38
#
#       ...              feature12          feature13    feature14  \
# 0     ...            ind_var13_0        num_var13_0  num_var42_0
# 1     ...      imp_op_var41_ult1        ind_var12_0    ind_var13
# 2     ...              num_var13        saldo_var13   num_var8_0
# 3     ...      imp_op_var39_ult1          ind_var13  num_var39_0
# 4     ...              ind_var13        num_var13_0   ind_var8_0
# 5     ...            ind_var39_0        ind_var12_0    ind_var13
# 6     ...            saldo_var13        num_var39_0  ind_var13_0
# 7     ...                  var38  imp_op_var41_ult1  num_var12_0
# 8     ...            num_var13_0        num_var42_0   num_var8_0
# 9     ...            num_var41_0          num_var13    ind_var13
#
#                  feature15                feature16                feature17  \
# 0               num_var8_0  imp_op_var41_efect_ult1           num_var22_ult3
# 1              ind_var13_0              num_var42_0           num_var45_ult3
# 2               ind_var8_0          num_var45_hace3           num_var22_ult3
# 3          num_var45_hace3           num_var22_ult3  imp_op_var39_efect_ult1
# 4          num_var45_hace3           num_var22_ult3        saldo_var13_corto
# 5              num_var13_0              num_var42_0               num_var8_0
# 6  imp_op_var41_efect_ult1           num_var45_ult3           num_var22_ult3
# 7              num_var13_0              num_var42_0  imp_op_var39_efect_ult1
# 8               ind_var8_0          num_var45_hace3           num_var22_ult3
# 9              num_var13_0              num_var42_0  imp_op_var41_efect_ult1
#
#                       feature18                     feature19  \
# 0               ind_var13_corto             saldo_var13_corto
# 1               ind_var13_corto             saldo_var13_corto
# 2               num_var13_corto  saldo_medio_var13_corto_ult3
# 3               ind_var13_corto             saldo_var13_corto
# 4  saldo_medio_var13_corto_ult3  saldo_medio_var13_corto_ult1
# 5       imp_op_var41_efect_ult1                num_var22_ult3
# 6       imp_op_var39_efect_ult1             saldo_var13_corto
# 7               ind_var13_corto               num_var13_corto
# 8       imp_op_var39_efect_ult1               num_var13_corto
# 9                num_var45_ult3       imp_op_var39_efect_ult1
#
#                       feature20 combinedAUC
# 0          ind_var43_recib_ult1    0.814596
# 1          ind_var43_recib_ult1    0.812961
# 2          ind_var43_recib_ult1    0.812723
# 3  saldo_medio_var13_corto_ult1    0.812225
# 4          ind_var43_recib_ult1    0.812082
# 5             saldo_var13_corto    0.812064
# 6          ind_var43_recib_ult1    0.811874
# 7  saldo_medio_var13_corto_ult1    0.811831
# 8             saldo_var13_corto    0.811699
# 9               ind_var13_corto    0.811232
#
# [10 rows x 22 columns]

# %%
feats15.head(5)
# Out:
#    Unnamed: 0 feature1                feature2   feature3  \
# 0           0    var15             saldo_var42  num_var35
# 1           1    var15             saldo_var42  num_var35
# 2           2    var15  saldo_medio_var5_hace2   num_var4
# 3           3    var15             saldo_var42   num_var4
# 4           4    var15             saldo_var42  num_var35
#
#               feature4                feature5    feature6 feature7  \
# 0             num_var4   saldo_medio_var5_ult1  saldo_var5    var38
# 1             num_var4               num_var30       var36    var38
# 2  num_meses_var5_ult3               num_var42       var36    var38
# 3           saldo_var5               num_var42    ind_var5    var38
# 4           saldo_var5  saldo_medio_var5_hace3       var36    var38
#
#                    feature8           feature9     ...              feature12  \
# 0               num_var30_0  imp_op_var41_ult1     ...            ind_var13_0
# 1  num_meses_var39_vig_ult3        num_var30_0     ...      imp_op_var41_ult1
# 2  num_meses_var39_vig_ult3        num_var30_0     ...              num_var13
# 3  num_meses_var39_vig_ult3        num_var30_0     ...      imp_op_var39_ult1
# 4               ind_var39_0        ind_var41_0     ...              ind_var13
#
#      feature13    feature14        feature15                feature16  \
# 0  num_var13_0  num_var42_0       num_var8_0  imp_op_var41_efect_ult1
# 1  ind_var12_0    ind_var13      ind_var13_0              num_var42_0
# 2  saldo_var13   num_var8_0       ind_var8_0          num_var45_hace3
# 3    ind_var13  num_var39_0  num_var45_hace3           num_var22_ult3
# 4  num_var13_0   ind_var8_0  num_var45_hace3           num_var22_ult3
#
#                  feature17                     feature18  \
# 0           num_var22_ult3               ind_var13_corto
# 1           num_var45_ult3               ind_var13_corto
# 2           num_var22_ult3               num_var13_corto
# 3  imp_op_var39_efect_ult1               ind_var13_corto
# 4        saldo_var13_corto  saldo_medio_var13_corto_ult3
#
#                       feature19                     feature20 combinedAUC
# 0             saldo_var13_corto          ind_var43_recib_ult1    0.814596
# 1             saldo_var13_corto          ind_var43_recib_ult1    0.812961
# 2  saldo_medio_var13_corto_ult3          ind_var43_recib_ult1    0.812723
# 3             saldo_var13_corto  saldo_medio_var13_corto_ult1    0.812225
# 4  saldo_medio_var13_corto_ult1          ind_var43_recib_ult1    0.812082
#
# [5 rows x 22 columns]
